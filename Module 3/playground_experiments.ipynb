# %% [markdown]
# # Run Experiments in Playground

# %% [markdown]
# ### Setup

# %%
# Or you can use a .env file
from dotenv import load_dotenv
load_dotenv(dotenv_path=r"C:\Users\Hunar Bhatia\OneDrive\Desktop\MAT_494_Langchain\.env", override=True)

# %% [markdown]
# ### Create a Dataset

# %% [markdown]
# Let's create a toy example dataset to run experiments over for a prompt

# %%
from langsmith import Client

example_inputs = [
("What would be your starter pokemon?", "charmander")
]

client = Client()
dataset_name = "Sample Questions"

dataset = client.create_dataset(
  dataset_name=dataset_name, description="Pokemon Question",
)

inputs = [{"question": input_prompt} for input_prompt, _ in example_inputs]
outputs = [{"output": output_answer} for _, output_answer in example_inputs]

client.create_examples(
  inputs=inputs,
  outputs=outputs,
  dataset_id=dataset.id,
)

# %% [markdown]
# ![image.png](attachment:244652f5-6117-4200-ac5c-a4289efa78b8.png)
